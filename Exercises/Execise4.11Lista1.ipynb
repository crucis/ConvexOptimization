# %% [markdown]
# # Exercício 4.11 do livro texto

# %%
import sys
if '..' not in sys.path:
    sys.path.append('..')
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import time
import seaborn as sns
from autograd import jacobian

from functions import functionObj, order4_polynomial
from models.optimizers import GoldenSectionSearch

# %%
func = functionObj(order4_polynomial)
x1_region = [-np.pi, np.pi]
x2_region = [-np.pi, np.pi]

x1 = np.linspace(*x1_region)
x2 = np.linspace(*x2_region)

xx, yy = np.meshgrid(x1, x2)

z = func([xx, yy], save_eval=False)
z.shape
# Out:
# (50, 50)

# %%
fig = plt.figure()
fig.set_figheight(10)
fig.set_figwidth(14)
ax = fig.add_subplot(111, projection = '3d')
img = ax.plot_surface(xx, yy, z, cmap = cm.viridis, alpha = 0.9)
ax.contour(xx, yy, z, cmap = cm.viridis, linestyles = "solid", offset = -40)
plt.colorbar(img)
plt.show()
